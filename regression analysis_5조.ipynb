# %%
import pandas as pd

# 데이터셋 분리 함수
from sklearn.model_selection import train_test_split
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"]
data = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names, na_values="?")
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
numerical_columns=  ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin"]

### figsize()는 plot()의 기본 크기를 지정합니다.
fig = plt.figure(figsize = (16, 20))
ax = fig.gca()  # Axes 생성
# origin, acceleration, horsepower, weight
### gca()
### gca()로 현재의 Axes를, gcf()로 현재의 Figure 객체를 구할 수 있다.

data[numerical_columns].hist(ax=ax)
plt.show()
# Out:
# <ipython-input-47-d6f8dadc77b5>:10: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data[numerical_columns].hist(ax=ax)

# %%
# 'car name' 열은 숫자 데이터가 아니므로 상관계수 매트릭스 계산에서 제외
data_numeric = data.drop('car name', axis=1)

# 상관계수 매트릭스 계산
correlation_matrix = data_numeric.corr()

# 상관계수 매트릭스 출력
print(correlation_matrix)

# 상관계수 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Auto MPG Dataset')
plt.show()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# model year    0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration  model year    origin
# mpg               0.423329    0.580541  0.565209
# cylinders        -0.504683   -0.345647 -0.568932
# displacement     -0.543800   -0.369855 -0.614535
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.416839   -0.309120 -0.585005
# ...

# %%
# NaN 값이 있는 행 제거
data = data.dropna()

data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_x_data = data.loc[:,['origin', 'acceleration', 'horsepower']]

df_x_data
# Out:
#      origin  acceleration  horsepower
# 0         1          12.0       130.0
# 1         1          11.5       165.0
# 2         1          11.0       150.0
# 3         1          12.0       150.0
# 4         1          10.5       140.0
# ..      ...           ...         ...
# 393       1          15.6        86.0
# 394       2          24.6        52.0
# 395       1          11.6        84.0
# 396       1          18.6        79.0
# 397       1          19.4        82.0
#
# [392 rows x 3 columns]

# %%
print(df_x_data.isnull().sum())
# Out:
# origin          0
# acceleration    0
# horsepower      0
# dtype: int64

# %%
df_y_data = data['mpg']

df_y_data
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, test_size=0.2, random_state=42)

X_train
# Out:
#      origin  acceleration  horsepower
# 260       1          18.7       110.0
# 184       1          14.9        92.0
# 174       1          14.5        97.0
# 64        1          13.5       150.0
# 344       1          16.4        64.0
# ..      ...           ...         ...
# 72        1          12.5       150.0
# 107       1          15.0       100.0
# 272       1          17.6        85.0
# 352       1          20.7        65.0
# 103       1          14.0       150.0
#
# [313 rows x 3 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313 entries, 260 to 103
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   origin        313 non-null    int64
#  1   acceleration  313 non-null    float64
#  2   horsepower    313 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 9.8 KB

# %%
print(X_train.isnull().sum())
# Out:
# origin          0
# acceleration    0
# horsepower      0
# dtype: int64

# %%
# 선형 회귀 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# 모델의 회귀 계수 출력
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Mean Squared Error: 20.725658205392584
# R^2 Score: 0.5939376690114946
# Intercept: 45.57173462909056
# Coefficient: [ 2.46839024 -0.54024696 -0.16650362]

# %%
import pandas as pd

# 데이터셋 분리 함수
from sklearn.model_selection import train_test_split
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"]
data = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names, na_values="?")
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
numerical_columns=  ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin"]

### figsize()는 plot()의 기본 크기를 지정합니다.
fig = plt.figure(figsize = (16, 20))
ax = fig.gca()  # Axes 생성
# origin, acceleration, horsepower, weight
### gca()
### gca()로 현재의 Axes를, gcf()로 현재의 Figure 객체를 구할 수 있다.

data[numerical_columns].hist(ax=ax)
plt.show()
# Out:
# <ipython-input-60-d6f8dadc77b5>:10: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data[numerical_columns].hist(ax=ax)

# %%
# NaN 값이 있는 행 제거
data = data.dropna()
data = pd.get_dummies(data, columns=['origin'])

data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year                   car name  origin_1  origin_2  origin_3
# ...

# %%
df_x_data = data.loc[:,['origin_1', 'origin_2', 'origin_3', 'acceleration', 'horsepower']]

df_x_data
# Out:
#      origin_1  origin_2  origin_3  acceleration  horsepower
# 0        True     False     False          12.0       130.0
# 1        True     False     False          11.5       165.0
# 2        True     False     False          11.0       150.0
# 3        True     False     False          12.0       150.0
# 4        True     False     False          10.5       140.0
# ..        ...       ...       ...           ...         ...
# 393      True     False     False          15.6        86.0
# 394     False      True     False          24.6        52.0
# 395      True     False     False          11.6        84.0
# 396      True     False     False          18.6        79.0
# 397      True     False     False          19.4        82.0
#
# [392 rows x 5 columns]

# %%
print(df_x_data.isnull().sum())
# Out:
# origin_1        0
# origin_2        0
# origin_3        0
# acceleration    0
# horsepower      0
# dtype: int64

# %%
df_y_data = data['mpg']

df_y_data
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(df_x_data, df_y_data, test_size=0.2, random_state=42)

X_train
# Out:
#      origin_1  origin_2  origin_3  acceleration  horsepower
# 260      True     False     False          18.7       110.0
# 184      True     False     False          14.9        92.0
# 174      True     False     False          14.5        97.0
# 64       True     False     False          13.5       150.0
# 344      True     False     False          16.4        64.0
# ..        ...       ...       ...           ...         ...
# 72       True     False     False          12.5       150.0
# 107      True     False     False          15.0       100.0
# 272      True     False     False          17.6        85.0
# 352      True     False     False          20.7        65.0
# 103      True     False     False          14.0       150.0
#
# [313 rows x 5 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313 entries, 260 to 103
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   origin_1      313 non-null    bool
#  1   origin_2      313 non-null    bool
#  2   origin_3      313 non-null    bool
#  3   acceleration  313 non-null    float64
#  4   horsepower    313 non-null    float64
# dtypes: bool(3), float64(2)
# memory usage: 8.3 KB

# %%
print(X_train.isnull().sum())
# Out:
# origin_1        0
# origin_2        0
# origin_3        0
# acceleration    0
# horsepower      0
# dtype: int64

# %%
# 선형 회귀 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# 모델의 회귀 계수 출력
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Mean Squared Error: 20.763083853035592
# R^2 Score: 0.5932044162689245
# Intercept: 50.492178521132004
# Coefficient: [-2.39939049 -0.17355797  2.57294847 -0.53899185 -0.16690644]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# get_linear_reg_eval 함수 정의
def get_linear_reg_eval(model_name, params=None, X_data_n=None, y_target_n=None, verbose=True, return_coeff=True):
    coeff_df = pd.DataFrame()
    if verbose:
        print('####### ', model_name , '#######')
    for param in params:
        if model_name =='Ridge':
            model = Ridge(alpha=param)
        elif model_name =='Lasso':
            model = Lasso(alpha=param)
        elif model_name =='ElasticNet':
            model = ElasticNet(alpha=param, l1_ratio=0.7)
        neg_mse_scores = cross_val_score(model, X_data_n, y_target_n, scoring="neg_mean_squared_error", cv=5)
        avg_rmse = np.mean(np.sqrt(-1 * neg_mse_scores))
        print('alpha {0}일 때 5 폴드 세트의 평균 RMSE: {1:.3f} '.format(param, avg_rmse))
        # 모델을 다시 학습하여 회귀 계수 추출
        model.fit(X_data_n, y_target_n)
        if return_coeff:
            # alpha에 따른 피처별 회귀 계수를 Series로 변환하고 이를 DataFrame의 컬럼으로 추가.
            coeff = pd.Series(data=model.coef_, index=X_data_n.columns)
            colname = 'alpha:' + str(param)
            coeff_df[colname] = coeff
    return coeff_df

# 라쏘에 사용될 alpha 파라미터의 값들을 정의하고 get_linear_reg_eval() 함수 호출
lasso_alphas = [0.07, 0.1, 0.5, 1, 3]
coeff_lasso_df = get_linear_reg_eval('Lasso', params=lasso_alphas, X_data_n=df_x_data, y_target_n=df_y_data)

# 결과 확인
print(coeff_lasso_df)
# Out:
# #######  Lasso #######
# alpha 0.07일 때 5 폴드 세트의 평균 RMSE: 4.993
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 5.003
# alpha 0.5일 때 5 폴드 세트의 평균 RMSE: 5.215
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 5.310
# alpha 3일 때 5 폴드 세트의 평균 RMSE: 5.418
#               alpha:0.07  alpha:0.1  alpha:0.5   alpha:1   alpha:3
# origin_1       -2.108033  -2.021070  -0.838307 -0.000000 -0.000000
# origin_2        0.000000   0.000000   0.000000  0.000000  0.000000
# origin_3        2.089360   1.940497   0.000000  0.000000  0.000000
# acceleration   -0.473521  -0.472353  -0.455866 -0.346472 -0.000000
# horsepower     -0.161171  -0.162129  -0.174856 -0.174283 -0.155815

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"]
data = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names, na_values="?")

print(data.isna().sum())

# 'horsepower' 열에서 결측치를 포함하는 행 제거
data.dropna(subset=['horsepower'], inplace=True)

# 데이터 정보 확인
print(data.info())

print(data.isna().sum())
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car name      392 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 30.6+ KB
# None
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# 데이터 로드 및 준비
column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"]
data = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names, na_values="?")

# 결측치 제거
data.dropna(subset=['horsepower'], inplace=True)

# 'origin' 열 원-핫 인코딩
origin_dummies = pd.get_dummies(data['origin'], prefix='origin')

# 원-핫 인코딩된 데이터를 기존 데이터프레임에 추가
data = pd.concat([data, origin_dummies], axis=1)
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin                   car name  origin_1  origin_2  \
# ...

# %%
# 'car name' 열은 숫자 데이터가 아니므로 제외
data_numeric = data.drop(['car name', 'origin'], axis=1)

# 필요한 특성 선택 (원-핫 인코딩된 'origin' 포함)
features = ["acceleration", "horsepower", "weight", "origin_1", "origin_2", "origin_3"]
target = data["mpg"]

# 데이터 분할: 훈련 세트와 테스트 세트
X_train, X_test, y_train, y_test = train_test_split(data_numeric[features], target, test_size=0.15, random_state=50)

# 스케일러 객체 생성 및 적용
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 선형 회귀 모델 생성 및 학습
model = LinearRegression()
model.fit(X_train_scaled, y_train)

# 테스트 데이터에 대한 예측
predictions = model.predict(X_test_scaled)

# 성능 평가
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
print("Coefficients:", model.coef_)
# Out:
# Mean Squared Error: 9.572536366867308
# R^2 Score: 0.7557675271137845
# Coefficients: [-0.09797626 -2.39826263 -3.95192633 -0.55597508 -0.04006712  0.69838134]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 실제 값과 예측 값의 비교 산점도
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, alpha=0.6, color='b')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual MPG')
plt.ylabel('Predicted MPG')
plt.title('Actual vs. Predicted MPG')
plt.show()

# 회귀 계수 시각화
feature_names = ["acceleration", "horsepower", "weight", "origin_1", "origin_2", "origin_3"]
coefficients = model.coef_

plt.figure(figsize=(10, 6))
sns.barplot(x=coefficients, y=feature_names, palette='coolwarm')
plt.title('Regression Coefficients')
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.show()
# Out:
# <ipython-input-55-524eb1823c4e>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=coefficients, y=feature_names, palette='coolwarm')
